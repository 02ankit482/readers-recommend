# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv("C:/Users/hp/OneDrive/Documents/python/book recommender system/data/archive/Books.csv" , dtype = str )

# %%
books.head(4)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
#
#             Book-Author Year-Of-Publication                Publisher  \
# 0    Mark P. O. Morford                2002  Oxford University Press
# 1  Richard Bruce Wright                2001    HarperFlamingo Canada
# 2          Carlo D'Este                1991          HarperPerennial
# 3      Gina Bari Kolata                1999     Farrar Straus Giroux
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
#
# ...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]

# %%
books.head(3)
# Out:
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher                                        Image-URL-L
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2          HarperPerennial  http://images.amazon.com/images/P/0060973129.0...

# %%
books.rename(columns={
    "Book-Title": "Title",
    "Book-Author": "Author",
    "Year-Of-Publication": "year",
    "publisher": "publisher",
    "Image-URL-L": "img_url"
},inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  year                   Publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                              img_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv("C:/Users/hp/OneDrive/Documents/python/book recommender system/data/archive/Users.csv", dtype= str)

# %%
users.head()
# Out:
#   User-ID                            Location   Age
# 0       1                  nyc, new york, usa   NaN
# 1       2           stockton, california, usa  18.0
# 2       3     moscow, yukon territory, russia   NaN
# 3       4           porto, v.n.gaia, portugal  17.0
# 4       5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings = pd.read_csv("C:/Users/hp/OneDrive/Documents/python/book recommender system/data/archive/Ratings.csv", dtype= str)

# %%
ratings.head(6)
# Out:
#   User-ID        ISBN Book-Rating
# 0  276725  034545104X           0
# 1  276726  0155061224           5
# 2  276727  0446520802           0
# 3  276729  052165615X           3
# 4  276729  0521795028           6
# 5  276733  2080674722           0

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings.rename(columns={
    "User-ID": "user_id",
    "Book-Rating": "rating",
},inplace=True)

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() >200

# %%
x
# Out:
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: user_id, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index

# %%
y
# Out:
# Index(['11676', '198711', '153662', '98391', '35859', '212898', '278418',
#        '76352', '110973', '235105',
#        ...
#        '260183', '73681', '44296', '155916', '9856', '274808', '28634',
#        '59727', '268622', '188951'],
#       dtype='object', length=899)

# %%
ratings[ratings['user_id'].isin(y)]
# Out:
#         user_id        ISBN rating
# 1456     277427  002542730X     10
# 1457     277427  0026217457      0
# 1458     277427  003008685X      8
# 1459     277427  0030615321      0
# 1460     277427  0060002050      0
# ...         ...         ...    ...
# 1147612  275970  3829021860      0
# 1147613  275970  4770019572      0
# 1147614  275970   896086097      0
# 1147615  275970  9626340762      8
# 1147616  275970  9626344990      0
#
# [526356 rows x 3 columns]

# %%
ratings_with_books = ratings.merge(books, on = "ISBN")

# %%
ratings_with_books.head(78)
# Out:
#    user_id        ISBN rating                 Title           Author  year  \
# 0   276725  034545104X      0  Flesh Tones: A Novel       M. J. Rose  2002
# 1     2313  034545104X      5  Flesh Tones: A Novel       M. J. Rose  2002
# 2     6543  034545104X      0  Flesh Tones: A Novel       M. J. Rose  2002
# 3     8680  034545104X      5  Flesh Tones: A Novel       M. J. Rose  2002
# 4    10314  034545104X      9  Flesh Tones: A Novel       M. J. Rose  2002
# ..     ...         ...    ...                   ...              ...   ...
# 73   19371  0446520802      4          The Notebook  Nicholas Sparks  1996
# 74   23768  0446520802      6          The Notebook  Nicholas Sparks  1996
# 75   24878  0446520802      7          The Notebook  Nicholas Sparks  1996
# 76   26525  0446520802     10          The Notebook  Nicholas Sparks  1996
# 77   27617  0446520802      9          The Notebook  Nicholas Sparks  1996
#
# ...

# %%
ratings_with_books.shape
# Out:
# (1031136, 8)

# %%
num_rating = ratings_with_books.groupby('Title')['rating'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                Title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       4
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4   Beyond IBM: Leadership Marketing and Finance ...       1

# %%
num_rating.rename(columns={'rating': 'num_of_rating'},inplace=True)

# %%
num_rating.head()
# Out:
#                                                Title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              4
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4   Beyond IBM: Leadership Marketing and Finance ...              1

# %%
ratings_with_books.head()
# Out:
#   user_id        ISBN rating                 Title      Author  year  \
# 0  276725  034545104X      0  Flesh Tones: A Novel  M. J. Rose  2002
# 1    2313  034545104X      5  Flesh Tones: A Novel  M. J. Rose  2002
# 2    6543  034545104X      0  Flesh Tones: A Novel  M. J. Rose  2002
# 3    8680  034545104X      5  Flesh Tones: A Novel  M. J. Rose  2002
# 4   10314  034545104X      9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher                                            img_url
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...

# %%
final_rating = ratings_with_books.merge(num_rating, on='Title')

# %%
final_rating.head(3)
# Out:
#   user_id        ISBN rating                 Title      Author  year  \
# 0  276725  034545104X      0  Flesh Tones: A Novel  M. J. Rose  2002
# 1    2313  034545104X      5  Flesh Tones: A Novel  M. J. Rose  2002
# 2    6543  034545104X      0  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher                                            img_url  \
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
#
#    num_of_rating
# 0             60
# 1             60
# 2             60

# %%
final_rating.shape
# Out:
# (1031136, 9)

# %%
final_rating = final_rating[final_rating['num_of_rating']>=50]

# %%
final_rating.sample(10)
# Out:
#        user_id        ISBN rating  \
# 306557  158226  0451191145      0
# 56027   104057  0671028375      0
# 255880   75701  0060085444      9
# 465610   70192  0425080021      4
# 37803   110912  0804114986     10
# 192920  172512  0553284789      9
# 303266  221445  0671797050      0
# 342460   16106  0142002267      9
# 313177  116031  0718136039      0
# 25420   207531  0446611212      8
#
#                                                     Title            Author  \
# 306557                                     Atlas Shrugged          Ayn Rand
# 56027                                        Fatal Voyage      Kathy Reichs
# 255880  She Went All the Way (Avon Light Contemporary ...      Meggin Cabot
# 465610                                               Dune     Frank Herbert
# 37803                           The Bonesetter's Daughter           Amy Tan
# 192920  F Is for Fugitive (Kinsey Millhone Mysteries (...       Sue Grafton
# ...

# %%
final_rating.shape
# Out:
# (288740, 9)

# %%
final_rating.drop_duplicates(['user_id','Title'], inplace=True)

# %%
final_rating.shape
# Out:
# (285518, 9)

# %%
final_rating
# Out:
#        user_id        ISBN rating                 Title  \
# 0       276725  034545104X      0  Flesh Tones: A Novel
# 1         2313  034545104X      5  Flesh Tones: A Novel
# 2         6543  034545104X      0  Flesh Tones: A Novel
# 3         8680  034545104X      5  Flesh Tones: A Novel
# 4        10314  034545104X      9  Flesh Tones: A Novel
# ...        ...         ...    ...                   ...
# 730559  223942  0061092096      0  Love in Another Town
# 730561  231210  0061092096      0  Love in Another Town
# 730562  238781  0061092096      5  Love in Another Town
# 730563  244349  0061092096      0  Love in Another Town
# 730564  258352  0061092096      0  Love in Another Town
#
#                          Author  year         Publisher  \
# 0                    M. J. Rose  2002  Ballantine Books
# 1                    M. J. Rose  2002  Ballantine Books
# 2                    M. J. Rose  2002  Ballantine Books
# 3                    M. J. Rose  2002  Ballantine Books
# ...

# %%
book_pivot = final_rating.pivot_table(columns='user_id',index='Title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             100001  100002  100004  \
# Title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# stardust                                               NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (2444, 47994)

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             100001  100002  100004  \
# Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[256,:].values.reshape(1,-1), n_neighbors=7)

# %%
distance
# Out:
# array([[ 0.        , 44.48595284, 45.50824101, 45.66180023, 45.82575695,
#         46.21688003, 46.35730795]])

# %%
suggestion
# Out:
# array([[ 256,   65,  770, 2114, 1575,  753, 1713]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Bittersweet', 'A Secret Affair', 'Ground Zero and Beyond', 'The Ring',
#        'Special Delivery: A Novel', 'Going Home', 'The Blooding'],
#       dtype='object', name='Title')

# %%
book_pivot.index[3]
# Out:
# '1st to Die: A Novel'

# %%
book_pivot.index
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='Title', length=2444)

# %%
books_name = book_pivot.index

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl','wb'))
pickle.dump(books_name,open('artifacts/books_name.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=7)

    for i in range(len(suggestion)):
        books = book_pivot.index[suggestion[i]]
        for j in books:
            print(j)

# %%
book_name = 'YOU BELONG TO ME'
recommend_book(book_name)
# Out:
# YOU BELONG TO ME
# Reasonable Doubt
# The Blooding
# Ground Zero and Beyond
# Women in His Life
# Blood and Gold (Rice, Anne, Vampire Chronicles.)
# A Secret Affair
